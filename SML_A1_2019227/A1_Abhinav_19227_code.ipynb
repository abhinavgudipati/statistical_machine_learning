# %%
import numpy as np 
import scipy
from scipy import stats
from scipy.stats import norm
import matplotlib.pyplot as plt

# %% [markdown]
# # 1 A

# %%
mean = 2 
standard_Deviation = 1 

x_Values = np.arange(-5,5,0.1)
y_Values = scipy.stats.norm(mean,standard_Deviation)

plt.plot(x_Values,y_Values.pdf(x_Values))

# %% [markdown]
# # 1 B

# %%
#1(B)
mean = 5 
standard_Deviation = 1 

x_Values = np.arange(-10,10,0.1)
y_Values = scipy.stats.norm(mean,standard_Deviation) 

plt.plot(x_Values,y_Values.pdf(x_Values))

# %% [markdown]
# # 1 C

# %%
#1(C)
output = np.exp(-0.5*((x_Values-2)**2 - (x_Values-5)**2));

plt.plot(x_Values,output)

# %% [markdown]
# # 3 B

# %%
P_w1 = 0.5
P_w2 = 0.5
x = np.arange(-40, 40, 0.001)
a1 = 3
x1 = (1 + ((x - a1)) ** 2);
d1 = (1 * np.pi * x1)
mul1 = (1 / d1)
P_1_x = mul1 * P_w1
#given
a2 = 5
x2 = (1 + ((x - a2)) ** 2)
d2 = (1 * np.pi * x2)
mul2 = (1 / d2)
P_2_x = mul2 * P_w2

plt.plot(x, P_1_x / (P_1_x + P_2_x))

plt.show()
